# %% [markdown]
# # ARIMAX_SE+N with GRIDSEARCH_CV and PCA on ADM0, QUARTERLY

# %%
import pandas as pd

# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)

import warnings
warnings.simplefilter('ignore')

import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)
    
import time
import datetime

import os

# %% [markdown]
# ## Model Specifications

# %%
TARGET_VARIABLE = "SUM(FATALITIES)"
SEASONAL_PERIODICITY = 4 # for data frequency & seasonality S

SEASONALITY = False
NEIGHBORS = True # X_N
SOCIO_ECO_VARS = True # X_SE
N_LAGS_X = 1 # todo: remove or change behavior from max lags to lag
DIM_REDUCTION_METHOD = "PCA"

if SEASONALITY:
    CV_FOLDS = 5
else:
    CV_FOLDS = 1

# %%
MODEL_NAME = ""
if SEASONALITY:
    MODEL_NAME += "S" 
    
MODEL_NAME += "ARIMA"

if SOCIO_ECO_VARS and NEIGHBORS:
    MODEL_NAME += "X_SE+N"
    
if SOCIO_ECO_VARS and not NEIGHBORS:
    MODEL_NAME += "X_SE"
    
if not SOCIO_ECO_VARS and NEIGHBORS:
    MODEL_NAME += "X_N"
    
if SEASONAL_PERIODICITY ==  12:
    MODEL_NAME += "_MONTHLY"
elif SEASONAL_PERIODICITY == 4:
    MODEL_NAME += "_QUARTERLY"

MODEL_NAME
# Out:
# 'ARIMAX_SE+N_QUARTERLY'

# %% [markdown]
# ### Hyperparameter Grid

# %%
# create a set of sarima configs to try
PARAM_GRID = list()
# parameter options to try

### PCA
if NEIGHBORS or SOCIO_ECO_VARS:
    n_components = range(0, 4) # include up to three main components
else:
    n_components = [0]
    

### ARMA
p_params = range(4) # AR 3
d_params = range(2) # Differencing 1
q_params = range(4) # MA 3


### SEASONALITY
if SEASONALITY:
    P_params = range(3) # 5
    D_params = range(2) # 1
    Q_params = range(3) # 2
    
    ### TREND
    # t_params = ['n','c','t','ct'] # Form of Trend
    # t_params = ['n', 't', 'ct'] # Form of Trend
    t_params = ["n"]

    ### SEASONAL PERIODICITY
    m_params = [SEASONAL_PERIODICITY]   
else:
    P_params = [0]
    D_params = [0]
    Q_params = [0]

    t_params = ["n"] # Form of Trend

    m_params = [0] 

for n in n_components:
    for p in p_params:
        for d in d_params:
            for q in q_params:
                for P in P_params:
                    for D in D_params:
                        for Q in Q_params:
                            for m in m_params:
                                for t in t_params:
                                    cfg = [n, (p, d, q), (P, D, Q, m), t]
                                    PARAM_GRID.append(cfg)
len(PARAM_GRID)
# Out:
# 128

# %% [markdown]
# ## Model Training

# %%
from common_functions import *
from forecasters import *

# %% [markdown]
# #### Training Method

# %%
def varimax(target_variable="SUM(FATALITIES)", 
            target_country="MLI", 
            predictor_countries=["BFA"], 
            n_lags_X = N_LAGS_X, 
            seasonal_periodicity = SEASONAL_PERIODICITY):
        
    ### GET DATA
    y, X = getData(target_variable = target_variable, 
                   target_country = target_country, 
                   predictor_countries = predictor_countries,
                   socio_eco_vars = SOCIO_ECO_VARS,
                   n_lags_X = N_LAGS_X, 
                   seasonal_periodicity = SEASONAL_PERIODICITY)
    
    ### SPLIT DATA
    X_train, X_test, y_train, y_test = train_test_split(y = y,
                                                        X = X, 
                                                        forecast_horizon = SEASONAL_PERIODICITY)
    
    ### TRAINING WITH GRIDSEARCHCV
    gscv = GridSearchCV(param_grid = PARAM_GRID,
                        forecaster = TimeSeriesForecasterPCA_LinInt,
                        seasonal_periodicity = SEASONAL_PERIODICITY,
                        cv_folds = CV_FOLDS)
    training_res = gscv.train(X_train, y_train)

    if training_res is not None:
        model = gscv
        # print ARIMA summary
        print(training_res)
        print(model.best_model_result.mle_retvals)
        plt.tight_layout()
        try:
            model.best_model_result.plot_diagnostics(figsize=(16*0.7, 10*0.7), lags = SEASONAL_PERIODICITY+1)
        except: 
            pass
        best_parameters = str(model.best_model_cv_results)
        
    else:
        print("No model fitted --> Prediction with Naive Model ")
        model = NoChange().fit(X_train, y_train)
        best_parameters = np.nan
        
    ### PREDICTION
    prediction_results = model.evaluate_model(X_test, y_test, fh = SEASONAL_PERIODICITY)
    
    if prediction_results["FAT_PRED"].isnull().values.any():
        model = NoChange().fit(X_train, y_train)
        print("Model Prediction failed --> Prediction with Naive Model ")
        model = NoChange().fit(X_train, y_train)
        best_parameters = np.nan
        prediction_results = model.evaluate_model(X_test, y_test, fh = SEASONAL_PERIODICITY)


    
    ### ADJUST RESULT DF
    prediction_results["GID_0"] = target_country
    prediction_results["MONTH"] = pd.to_datetime(prediction_results["MONTH"].astype(str)) 
    prediction_results["PARAMETERS"] = best_parameters

    print(prediction_results)

    return prediction_results

# %% [markdown]
# #### Automated Training for all 234 Countries

# %%
acled_monthly_adm0 = pd.read_csv("../data/TB003_EVENT_OUTCOMES_MONTHLY_START_DATE.csv")
gid0_neighbors = pd.read_csv("../data/GID_0_Neighbours.csv")
# gid_list = acled_monthly_adm0["GID_0"].unique()[::-1] #reverse
gid_list = acled_monthly_adm0["GID_0"].unique()
len(gid_list)
# Out:
# 234

# %%
# warnings.simplefilter(action='ignore')

varimax_res = pd.DataFrame(columns=["MONTH", "FAT_PRED", "FAT_ACTUAL", "LC(FAT_PRED)", "LC(FAT_ACTUAL)", "GID_0", "PARAMETERS", "TIMESTAMP"])
csv_file = "../data/"+MODEL_NAME+"_PREDICTIONS.csv"

if os.path.exists(csv_file):
    existing_res = pd.read_csv("../data/"+MODEL_NAME+"_PREDICTIONS.csv")
    # print(existing_res)
    print("File already exists.")
    
else:
    varimax_res.to_csv(csv_file, index=False, mode="a", header=True)
    existing_res = varimax_res

for i, g in enumerate(gid_list):
# for i, g in enumerate(["XNC"]):
    print("######## "+g+" ("+str(i+1)+"/"+str(len(gid_list))+") #########")
    # print(existing_res[existing_res["GID_0"] == g])
    print(len(existing_res[existing_res["GID_0"] == g]))
    
    
    # skip country if results already exiast
    if len(existing_res[existing_res["GID_0"] == g]) > 0:
        print("Model for this country has already been fitted.")
        continue
    
    # add time series of neighboring  countries as predictor variables

    if NEIGHBORS == True:
        neighbor = gid0_neighbors[gid0_neighbors["GID_0"] == g]["NEIGHBOUR"].tolist()
    else:
        neighbor = []
    print("Neighbor countries: "+ str(neighbor))

    # measure time 
    st = time.time()

    res = varimax(target_variable = TARGET_VARIABLE,
                  target_country = g,
                  predictor_countries = neighbor,
                  n_lags_X = N_LAGS_X,
                  seasonal_periodicity = SEASONAL_PERIODICITY)

    # append country results to csv with timestamp
    res["TIMESTAMP"] = datetime.datetime.now()
    
    res.to_csv(csv_file, index=False, mode="a", header=False)

    et = time.time()
    elapsed_time = et - st
    print('Execution time:', time.strftime("%M:%S", time.gmtime(elapsed_time)))

    varimax_res = pd.concat([varimax_res, res], ignore_index=True)

    # break
# Out:
# File already exists.
# ######## ABW (1/234) #########
# 4
# Model for this country has already been fitted.
# ######## AFG (2/234) #########
# 4
# Model for this country has already been fitted.
# ######## AGO (3/234) #########
# 4
# Model for this country has already been fitted.
# ######## AIA (4/234) #########
# 4
# Model for this country has already been fitted.
# ######## ALA (5/234) #########
# 4
# Model for this country has already been fitted.
# ######## ALB (6/234) #########
# 4
# Model for this country has already been fitted.
# ######## AND (7/234) #########
# 4
# Model for this country has already been fitted.
# ######## ARE (8/234) #########
# 4
# Model for this country has already been fitted.
# ######## ARG (9/234) #########
# 4
# Model for this country has already been fitted.
# ######## ARM (10/234) #########
# 4
# Model for this country has already been fitted.
# ######## ASM (11/234) #########
# 4
# Model for this country has already been fitted.
# ######## ATA (12/234) #########
# 4
# Model for this country has already been fitted.
# ######## ATG (13/234) #########
# 4
# Model for this country has already been fitted.
# ######## AUS (14/234) #########
# 4
# Model for this country has already been fitted.
# ######## AUT (15/234) #########
# 4
# Model for this country has already been fitted.
# ######## AZE (16/234) #########
# 4
# Model for this country has already been fitted.
# ######## BDI (17/234) #########
# 4
# Model for this country has already been fitted.
# ######## BEL (18/234) #########
# 4
# Model for this country has already been fitted.
# ######## BEN (19/234) #########
# 4
# Model for this country has already been fitted.
# ######## BES (20/234) #########
# 4
# Model for this country has already been fitted.
# ######## BFA (21/234) #########
# 4
# Model for this country has already been fitted.
# ######## BGD (22/234) #########
# 4
# Model for this country has already been fitted.
# ######## BGR (23/234) #########
# 4
# Model for this country has already been fitted.
# ######## BHR (24/234) #########
# 4
# Model for this country has already been fitted.
# ######## BHS (25/234) #########
# 4
# Model for this country has already been fitted.
# ######## BIH (26/234) #########
# 4
# Model for this country has already been fitted.
# ######## BLM (27/234) #########
# 4
# Model for this country has already been fitted.
# ######## BLR (28/234) #########
# 4
# Model for this country has already been fitted.
# ######## BLZ (29/234) #########
# 4
# Model for this country has already been fitted.
# ######## BMU (30/234) #########
# 4
# Model for this country has already been fitted.
# ######## BOL (31/234) #########
# 4
# Model for this country has already been fitted.
# ######## BRA (32/234) #########
# 4
# Model for this country has already been fitted.
# ######## BRB (33/234) #########
# 4
# Model for this country has already been fitted.
# ######## BRN (34/234) #########
# 4
# Model for this country has already been fitted.
# ######## BTN (35/234) #########
# 4
# Model for this country has already been fitted.
# ######## BWA (36/234) #########
# 4
# Model for this country has already been fitted.
# ######## CAF (37/234) #########
# 4
# Model for this country has already been fitted.
# ######## CAN (38/234) #########
# 4
# Model for this country has already been fitted.
# ######## CHE (39/234) #########
# 4
# Model for this country has already been fitted.
# ######## CHL (40/234) #########
# 4
# Model for this country has already been fitted.
# ######## CHN (41/234) #########
# 4
# Model for this country has already been fitted.
# ######## CIV (42/234) #########
# 4
# Model for this country has already been fitted.
# 4
# Model for this country has already been fitted.
# ######## SLV (186/234) #########
# 4
# Model for this country has already been fitted.
# ######## SMR (187/234) #########
# 4
# Model for this country has already been fitted.
# ######## SOM (188/234) #########
# 4
# Model for this country has already been fitted.
# ######## SRB (189/234) #########
# 4
# Model for this country has already been fitted.
# ######## SSD (190/234) #########
# 4
# Model for this country has already been fitted.
# ######## STP (191/234) #########
# 4
# Model for this country has already been fitted.
# ######## SUR (192/234) #########
# 4
# Model for this country has already been fitted.
# ######## SVK (193/234) #########
# 4
# Model for this country has already been fitted.
# ######## SVN (194/234) #########
# 4
# Model for this country has already been fitted.
# ######## SWE (195/234) #########
# 4
# Model for this country has already been fitted.
# ######## SWZ (196/234) #########
# 4
# Model for this country has already been fitted.
# ######## SXM (197/234) #########
# 4
# Model for this country has already been fitted.
# ######## SYC (198/234) #########
# 4
# Model for this country has already been fitted.
# ######## SYR (199/234) #########
# 4
# Model for this country has already been fitted.
# ######## TCA (200/234) #########
# 4
# Model for this country has already been fitted.
# ######## TCD (201/234) #########
# 4
# Model for this country has already been fitted.
# ######## TGO (202/234) #########
# 4
# Model for this country has already been fitted.
# ######## THA (203/234) #########
# 4
# Model for this country has already been fitted.
# ######## TJK (204/234) #########
# 4
# Model for this country has already been fitted.
# ######## TKM (205/234) #########
# 4
# Model for this country has already been fitted.
# ######## TLS (206/234) #########
# 4
# Model for this country has already been fitted.
# ######## TON (207/234) #########
# 4
# Model for this country has already been fitted.
# ######## TTO (208/234) #########
# 4
# Model for this country has already been fitted.
# ######## TUN (209/234) #########
# 4
# Model for this country has already been fitted.
# ######## TUR (210/234) #########
# 4
# Model for this country has already been fitted.
# ######## TWN (211/234) #########
# 4
# Model for this country has already been fitted.
# ######## TZA (212/234) #########
# 4
# Model for this country has already been fitted.
# ######## UGA (213/234) #########
# 4
# Model for this country has already been fitted.
# ######## UKR (214/234) #########
# 0
# Neighbor countries: ['BLR', 'POL', 'RUS', 'MDA', 'ROU', 'HUN', 'SVK']
# Getting Data for UKR
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (17, 150)
# y: (17, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], 'cv_score': 0.07942169668091603, 'fold_results': [0.07942169668091603]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_UKR   No. Observations:                   13
# Model:                SARIMAX(3, 1, 2)   Log Likelihood                  -5.873
# Date:                 Sat, 03 Sep 2022   AIC                             25.745
# Time:                         20:10:59   BIC                             29.139
# Sample:                     01-31-2018   HQIC                            24.488
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0018      0.037     -0.049      0.961      -0.075       0.071
# ar.L1         -0.6735      0.747     -0.901      0.367      -2.138       0.791
# ar.L2          0.4344      0.773      0.562      0.574      -1.080       1.949
# ar.L3          0.3700      0.595      0.622      0.534      -0.796       1.536
# ma.L1          0.0591      0.869      0.068      0.946      -1.644       1.763
# ma.L2          0.9736     24.816      0.039      0.969     -47.666      49.613
# sigma2         0.0872      2.131      0.041      0.967      -4.090       4.265
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):                 0.60
# Prob(Q):                              0.64   Prob(JB):                         0.74
# Heteroskedasticity (H):               0.55   Skew:                             0.36
# Prob(H) (two-sided):                  0.58   Kurtosis:                         2.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 0.45173639075189914, 'gopt': array([ 0.03881516, -0.00128492,  0.00043356,  0.00047848, -0.00269817,
#        -0.00015763, -0.022078  ]), 'fcalls': 536, 'warnflag': 1, 'converged': False, 'iterations': 50}
# Evaluation started.
# TADDA: 1.2833529783329634
# Evaluation finished.
#        MONTH   FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  14.040319        65.0     -0.900183        0.578737   UKR
# 1 2021-07-01  51.140906        28.0      0.343032       -0.243622   UKR
# 2 2021-10-01  19.400422        20.0     -0.595362       -0.566395   UKR
# 3 2022-01-01  46.208753         9.0      0.243661       -1.308333   UKR
#
#                                           PARAMETERS
# 0  {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:20
# ######## URY (215/234) #########
# 0
# Neighbor countries: ['ARG', 'BRA']
# Getting Data for URY
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (17, 110)
# y: (17, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], 'cv_score': 0.0, 'fold_results': [0.0]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_URY   No. Observations:                   13
# Model:                         SARIMAX   Log Likelihood                  -4.150
# Date:                 Sat, 03 Sep 2022   AIC                             10.301
# Time:                         20:11:09   BIC                             10.866
# Sample:                     01-31-2018   HQIC                            10.185
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.1109      0.034      3.291      0.001       0.045       0.177
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.80   Jarque-Bera (JB):                 3.61
# Prob(Q):                              0.03   Prob(JB):                         0.16
# Heteroskedasticity (H):                nan   Skew:                             1.28
# Prob(H) (two-sided):                   nan   Kurtosis:                         2.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 0.31925707822629473, 'gopt': array([9.01770714e-05]), 'fcalls': 28, 'warnflag': 0, 'converged': True, 'iterations': 1}
# Evaluation started.
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   URY
# 1 2021-07-01       0.0         0.0           0.0             0.0   URY
# 2 2021-10-01       0.0         0.0           0.0             0.0   URY
# 3 2022-01-01       0.0         0.0           0.0             0.0   URY
#
#                                           PARAMETERS
# 0  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:09
# ######## USA (216/234) #########
# 0
# Neighbor countries: ['CAN', 'MEX']
# Getting Data for USA
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (9, 109)
# y: (9, 1)
# ------------------------------------------------
# Training started.
# GridSearchCV failed. Insufficient data for cross validation.
# No model fitted --> Prediction with Naive Model
# TADDA: 0.6019094672492973
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  3.637586    3.871201           0.0        0.233615   USA
# 1 2021-07-01  3.637586    2.995732           0.0       -0.641854   USA
# 2 2021-10-01  3.637586    3.178054           0.0       -0.459532   USA
# 3 2022-01-01  3.637586    2.564949           0.0       -1.072637   USA
#
#    PARAMETERS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# Execution time: 00:01
# ######## UZB (217/234) #########
# 0
# Neighbor countries: ['TJK', 'KAZ', 'AFG', 'TKM', 'KGZ']
# Getting Data for UZB
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (17, 129)
# y: (17, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [2, (2, 0, 3), (0, 0, 0, 0), 'n'], 'cv_score': 0.26599630091765636, 'fold_results': [0.26599630091765636]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_UZB   No. Observations:                   13
# Model:                SARIMAX(2, 0, 3)   Log Likelihood                  -7.330
# Date:                 Sat, 03 Sep 2022   AIC                             30.660
# Time:                         20:11:25   BIC                             35.179
# Sample:                     01-31-2018   HQIC                            29.731
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0117      0.011      1.034      0.301      -0.010       0.034
# x2             0.0224      0.025      0.900      0.368      -0.026       0.071
# ar.L1          0.0147     43.252      0.000      1.000     -84.757      84.786
# ar.L2          0.9839     43.261      0.023      0.982     -83.806      85.773
# ma.L1         -0.8780     38.044     -0.023      0.982     -75.443      73.687
# ma.L2         -0.9206     82.898     -0.011      0.991    -163.397     161.556
# ma.L3          0.9126     46.604      0.020      0.984     -90.429      92.254
# sigma2         0.1078      1.019      0.106      0.916      -1.889       2.105
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.14   Jarque-Bera (JB):                 0.07
# Prob(Q):                              0.71   Prob(JB):                         0.96
# Heteroskedasticity (H):               3.00   Skew:                            -0.05
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 0.5638387162281828, 'gopt': array([-0.1925911 , -0.07818221, -0.00165713, -0.00262044,  0.00341166,
#         0.00811982, -0.00569134, -0.00622669]), 'fcalls': 657, 'warnflag': 1, 'converged': False, 'iterations': 50}
# Evaluation started.
# TADDA: 0.4241717632850854
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  2.026444         2.0      1.107388        1.098612   UZB
# 1 2021-07-01  0.815457         2.0      0.596337        1.098612   UZB
# 2 2021-10-01  0.804132         0.0      0.590079        0.000000   UZB
# 3 2022-01-01  0.814040         0.0      0.595557        0.000000   UZB
#
#                                           PARAMETERS
# 0  {'params': [2, (2, 0, 3), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [2, (2, 0, 3), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [2, (2, 0, 3), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [2, (2, 0, 3), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:13
# ######## VAT (218/234) #########
# 0
# Neighbor countries: ['ITA']
# Getting Data for VAT
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (9, 8)
# y: (9, 1)
# ------------------------------------------------
# Training started.
# GridSearchCV failed. Insufficient data for cross validation.
# No model fitted --> Prediction with Naive Model
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   VAT
# 1 2021-07-01       0.0         0.0           0.0             0.0   VAT
# 2 2021-10-01       0.0         0.0           0.0             0.0   VAT
# 3 2022-01-01       0.0         0.0           0.0             0.0   VAT
#
#    PARAMETERS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# Execution time: 00:01
# ######## VCT (219/234) #########
# 0
# Neighbor countries: []
# Getting Data for VCT
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (9, 79)
# y: (9, 1)
# ------------------------------------------------
# Training started.
# GridSearchCV failed. Insufficient data for cross validation.
# No model fitted --> Prediction with Naive Model
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   VCT
# 1 2021-07-01       0.0         0.0           0.0             0.0   VCT
# 2 2021-10-01       0.0         0.0           0.0             0.0   VCT
# 3 2022-01-01       0.0         0.0           0.0             0.0   VCT
#
#    PARAMETERS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# Execution time: 00:01
# ######## VEN (220/234) #########
# 0
# Neighbor countries: ['BRA', 'COL', 'GUY']
# Getting Data for VEN
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (17, 97)
# y: (17, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [2, (1, 0, 3), (0, 0, 0, 0), 'n'], 'cv_score': 0.49859992397333597, 'fold_results': [0.49859992397333597]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_VEN   No. Observations:                   13
# Model:                SARIMAX(1, 0, 3)   Log Likelihood                 -11.171
# Date:                 Sat, 03 Sep 2022   AIC                             36.341
# Time:                         20:11:41   BIC                             40.296
# Sample:                     01-31-2018   HQIC                            35.528
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0382      0.052     -0.727      0.467      -0.141       0.065
# x2            -0.0203      0.049     -0.415      0.678      -0.116       0.075
# ar.L1          0.9879      0.068     14.550      0.000       0.855       1.121
# ma.L1          0.1144      9.620      0.012      0.991     -18.740      18.969
# ma.L2          0.0466      8.744      0.005      0.996     -17.090      17.184
# ma.L3          0.9133      9.621      0.095      0.924     -17.943      19.770
# sigma2         0.1632      1.627      0.100      0.920      -3.026       3.352
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.34   Jarque-Bera (JB):                 0.77
# Prob(Q):                              0.56   Prob(JB):                         0.68
# Heteroskedasticity (H):               6.36   Skew:                             0.60
# Prob(H) (two-sided):                  0.10   Kurtosis:                         2.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 0.8592815139512177, 'gopt': array([-1.22601962e-04,  4.72707562e-04, -2.27603791e-04,  2.23700614e-05,
#        -4.51155890e-05, -7.18155846e-04,  1.71239178e-04]), 'fcalls': 576, 'warnflag': 1, 'converged': False, 'iterations': 50}
# Evaluation started.
# TADDA: 0.7323967459815628
# Evaluation finished.
#        MONTH   FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  51.161106        74.0     -0.488314       -0.125163   VEN
# 1 2021-07-01  37.060585        60.0     -0.803472       -0.331777   VEN
# 2 2021-10-01  80.028622        15.0     -0.047849       -1.670063   VEN
# 3 2022-01-01  75.994089        47.0     -0.098923       -0.571450   VEN
#
#                                           PARAMETERS
# 0  {'params': [2, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [2, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [2, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [2, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:12
# ######## VIR (221/234) #########
# 0
# Neighbor countries: []
# Getting Data for VIR
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (9, 25)
# y: (9, 1)
# ------------------------------------------------
# Training started.
# GridSearchCV failed. Insufficient data for cross validation.
# No model fitted --> Prediction with Naive Model
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   VIR
# 1 2021-07-01       0.0         0.0           0.0             0.0   VIR
# 2 2021-10-01       0.0         0.0           0.0             0.0   VIR
# 3 2022-01-01       0.0         0.0           0.0             0.0   VIR
#
#    PARAMETERS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# Execution time: 00:01
# ######## VNM (222/234) #########
# 0
# Neighbor countries: ['KHM', 'CHN', 'LAO']
# Getting Data for VNM
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (49, 115)
# y: (49, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [0, (1, 0, 3), (0, 0, 0, 0), 'n'], 'cv_score': 0.3319046544965909, 'fold_results': [0.3319046544965909]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_VNM   No. Observations:                   45
# Model:                SARIMAX(1, 0, 3)   Log Likelihood                 -57.847
# Date:                 Sat, 03 Sep 2022   AIC                            125.694
# Time:                         20:11:54   BIC                            134.727
# Sample:                     01-31-2010   HQIC                           129.061
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9930      0.014     70.290      0.000       0.965       1.021
# ma.L1         -0.9691      0.152     -6.363      0.000      -1.268      -0.671
# ma.L2         -0.1215      0.225     -0.540      0.589      -0.563       0.320
# ma.L3          0.2079      0.185      1.126      0.260      -0.154       0.570
# sigma2         0.7330      0.154      4.762      0.000       0.431       1.035
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                32.92
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.22   Skew:                             1.48
# Prob(H) (two-sided):                  0.01   Kurtosis:                         5.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 1.2854850595546738, 'gopt': array([ 2.49800181e-08, -1.41620049e-07, -1.04363185e-06, -9.47197876e-07,
#        -1.10309539e-06]), 'fcalls': 150, 'warnflag': 0, 'converged': True, 'iterations': 21}
# Evaluation started.
# TADDA: 0.33800513790068953
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  0.532553         0.0      0.426935             0.0   VNM
# 1 2021-07-01  0.447395         0.0      0.369765             0.0   VNM
# 2 2021-10-01  0.321329         0.0      0.278638             0.0   VNM
# 3 2022-01-01  0.318747         0.0      0.276682             0.0   VNM
#
#                                           PARAMETERS
# 0  {'params': [0, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [0, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [0, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [0, (1, 0, 3), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:11
# ######## VUT (223/234) #########
# 0
# Neighbor countries: []
# Getting Data for VUT
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (5, 79)
# y: (5, 1)
# ------------------------------------------------
# Training started.
# GridSearchCV failed. Insufficient data for cross validation.
# No model fitted --> Prediction with Naive Model
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   VUT
# 1 2021-07-01       0.0         0.0           0.0             0.0   VUT
# 2 2021-10-01       0.0         0.0           0.0             0.0   VUT
# 3 2022-01-01       0.0         0.0           0.0             0.0   VUT
#
#    PARAMETERS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# Execution time: 00:01
# ######## WLF (224/234) #########
# 0
# Neighbor countries: []
# Getting Data for WLF
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (5, 0)
# y: (5, 1)
# ------------------------------------------------
# Training started.
# GridSearchCV failed. Insufficient data for cross validation.
# No model fitted --> Prediction with Naive Model
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   WLF
# 1 2021-07-01       0.0         0.0           0.0             0.0   WLF
# 2 2021-10-01       0.0         0.0           0.0             0.0   WLF
# 3 2022-01-01       0.0         0.0           0.0             0.0   WLF
#
#    PARAMETERS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# Execution time: 00:01
# ######## WSM (225/234) #########
# 0
# Neighbor countries: []
# Getting Data for WSM
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (5, 79)
# y: (5, 1)
# ------------------------------------------------
# Training started.
# GridSearchCV failed. Insufficient data for cross validation.
# No model fitted --> Prediction with Naive Model
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   WSM
# 1 2021-07-01       0.0         0.0           0.0             0.0   WSM
# 2 2021-10-01       0.0         0.0           0.0             0.0   WSM
# 3 2022-01-01       0.0         0.0           0.0             0.0   WSM
#
#    PARAMETERS
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# Execution time: 00:01
# ######## XAR (226/234) #########
# 0
# Neighbor countries: ['SDN', 'SSD']
# Getting Data for XAR
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (100, 16)
# y: (100, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [0, (2, 1, 0), (0, 0, 0, 0), 'n'], 'cv_score': 0.7390342956789828, 'fold_results': [0.7390342956789828]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_XAR   No. Observations:                   96
# Model:                SARIMAX(2, 1, 0)   Log Likelihood                -166.154
# Date:                 Sat, 03 Sep 2022   AIC                            338.309
# Time:                         20:12:09   BIC                            345.970
# Sample:                     04-30-1997   HQIC                           341.405
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3535      0.085     -4.136      0.000      -0.521      -0.186
# ar.L2         -0.3541      0.084     -4.199      0.000      -0.519      -0.189
# sigma2         1.9281      0.202      9.522      0.000       1.531       2.325
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.25   Jarque-Bera (JB):                19.15
# Prob(Q):                              0.62   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.89   Skew:                             0.54
# Prob(H) (two-sided):                  0.08   Kurtosis:                         4.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 1.7307742407698132, 'gopt': array([-1.77415860e-06, -2.89777091e-06, -2.32427411e-06]), 'fcalls': 32, 'warnflag': 0, 'converged': True, 'iterations': 5}
# Evaluation started.
# TADDA: 1.3893263574986077
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  2.534757        13.0      0.569497        1.945910   XAR
# 1 2021-07-01  2.694144         2.0      0.613602        0.405465   XAR
# 2 2021-10-01  1.972795         0.0      0.396356       -0.693147   XAR
# 3 2022-01-01  2.160367        37.0      0.457541        2.944439   XAR
#
#                                           PARAMETERS
# 0  {'params': [0, (2, 1, 0), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [0, (2, 1, 0), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [0, (2, 1, 0), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [0, (2, 1, 0), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:10
# ######## XIT (227/234) #########
# 0
# Neighbor countries: ['ETH', 'KEN', 'SSD']
# Getting Data for XIT
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (100, 24)
# y: (100, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], 'cv_score': 0.0, 'fold_results': [0.0]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_XIT   No. Observations:                   96
# Model:                         SARIMAX   Log Likelihood                 -14.931
# Date:                 Sat, 03 Sep 2022   AIC                             31.863
# Time:                         20:12:19   BIC                             34.427
# Sample:                     04-30-1997   HQIC                            32.899
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0799      0.002     37.614      0.000       0.076       0.084
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):             13004.96
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.00   Skew:                             7.39
# Prob(H) (two-sided):                  0.00   Kurtosis:                        58.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 0.1555344533444163, 'gopt': array([0.00012513]), 'fcalls': 32, 'warnflag': 0, 'converged': True, 'iterations': 1}
# Evaluation started.
# TADDA: 0.5198603854199589
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         3.0           0.0        1.386294   XIT
# 1 2021-07-01       0.0         0.0           0.0        0.000000   XIT
# 2 2021-10-01       0.0         0.0           0.0        0.000000   XIT
# 3 2022-01-01       0.0         1.0           0.0        0.693147   XIT
#
#                                           PARAMETERS
# 0  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:10
# ######## XKK (228/234) #########
# 0
# Neighbor countries: ['CAF', 'SDN', 'SSD']
# Getting Data for XKK
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (100, 24)
# y: (100, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], 'cv_score': 0.44793986730701374, 'fold_results': [0.44793986730701374]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# ...
# Ljung-Box (L1) (Q):                   0.62   Jarque-Bera (JB):                 9.51
# Prob(Q):                              0.43   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.00   Skew:                             1.92
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 0.11652452417221247, 'gopt': array([0.00013528]), 'fcalls': 32, 'warnflag': 0, 'converged': True, 'iterations': 1}
# Evaluation started.
# TADDA: 0.0
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       0.0         0.0           0.0             0.0   XNC
# 1 2021-07-01       0.0         0.0           0.0             0.0   XNC
# 2 2021-10-01       0.0         0.0           0.0             0.0   XNC
# 3 2022-01-01       0.0         0.0           0.0             0.0   XNC
#
#                                           PARAMETERS
# 0  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:09
# ######## YEM (231/234) #########
# 0
# Neighbor countries: ['OMN', 'SAU']
# Getting Data for YEM
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (29, 106)
# y: (29, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [3, (3, 0, 0), (0, 0, 0, 0), 'n'], 'cv_score': 0.09603661597126223, 'fold_results': [0.09603661597126223]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_YEM   No. Observations:                   25
# Model:                SARIMAX(3, 0, 0)   Log Likelihood                 -12.189
# Date:                 Sat, 03 Sep 2022   AIC                             38.378
# Time:                         20:13:03   BIC                             46.910
# Sample:                     01-31-2015   HQIC                            40.744
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0009      0.092      0.010      0.992      -0.180       0.181
# x2            -0.0037      0.081     -0.046      0.964      -0.163       0.156
# x3             0.0664      0.104      0.638      0.524      -0.138       0.270
# ar.L1          0.4011      0.254      1.582      0.114      -0.096       0.898
# ar.L2          0.1643      0.285      0.577      0.564      -0.393       0.722
# ar.L3          0.4342      0.198      2.188      0.029       0.045       0.823
# sigma2         0.1174      0.034      3.464      0.001       0.051       0.184
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.54   Jarque-Bera (JB):                 7.83
# Prob(Q):                              0.46   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.62   Skew:                            -0.20
# Prob(H) (two-sided):                  0.52   Kurtosis:                         5.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 0.487557826332603, 'gopt': array([ 4.13936940e-05,  9.38142342e-06,  5.24543242e-05, -3.93962640e-08,
#         7.38086259e-06, -3.05943049e-06,  1.62208025e-05]), 'fcalls': 392, 'warnflag': 0, 'converged': True, 'iterations': 43}
# Evaluation started.
# TADDA: 0.34459100851160485
# Evaluation finished.
#        MONTH     FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  5519.941257      4258.0      0.042919       -0.216595   YEM
# 1 2021-07-01  5275.914445      3500.0     -0.002288       -0.412581   YEM
# 2 2021-10-01  5301.406426      5315.0      0.002532        0.005092   YEM
# 3 2022-01-01  5371.543187      2811.0      0.015672       -0.631733   YEM
#
#                                           PARAMETERS
# 0  {'params': [3, (3, 0, 0), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [3, (3, 0, 0), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [3, (3, 0, 0), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [3, (3, 0, 0), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:12
# ######## ZAF (232/234) #########
# 0
# Neighbor countries: ['LSO', 'MOZ', 'SWZ', 'BWA', 'ZWE', 'NAM']
# Getting Data for ZAF
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (100, 143)
# y: (100, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [3, (3, 1, 3), (0, 0, 0, 0), 'n'], 'cv_score': 0.18360889110355783, 'fold_results': [0.18360889110355783]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_ZAF   No. Observations:                   96
# Model:                SARIMAX(3, 1, 3)   Log Likelihood                -100.966
# Date:                 Sat, 03 Sep 2022   AIC                            221.931
# Time:                         20:13:16   BIC                            247.470
# Sample:                     04-30-1997   HQIC                           232.251
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1121      0.079      1.416      0.157      -0.043       0.267
# x2             0.0003      0.062      0.004      0.997      -0.121       0.122
# x3             0.0349      0.048      0.725      0.468      -0.059       0.129
# ar.L1          0.6326      0.218      2.907      0.004       0.206       1.059
# ar.L2         -0.9542      0.135     -7.042      0.000      -1.220      -0.689
# ar.L3          0.1789      0.209      0.854      0.393      -0.232       0.589
# ma.L1         -1.2684      0.343     -3.697      0.000      -1.941      -0.596
# ma.L2          1.3767      1.495      0.921      0.357      -1.553       4.306
# ma.L3         -0.7799      0.959     -0.814      0.416      -2.659       1.099
# sigma2         0.4741      0.574      0.827      0.408      -0.650       1.598
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                14.13
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.18   Skew:                            -0.39
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 1.051724739933978, 'gopt': array([ 2.67173927e-04,  1.85484201e-03,  2.46866743e-03, -6.09985631e-03,
#         2.26883845e-04,  3.47540268e-03,  1.19276505e-02, -4.88096896e-05,
#        -7.55200324e-04,  7.72684805e-04]), 'fcalls': 627, 'warnflag': 1, 'converged': False, 'iterations': 50}
# Evaluation started.
# TADDA: 0.79416264912752
# Evaluation finished.
#        MONTH   FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  40.700474        66.0     -0.363832        0.110348   ZAF
# 1 2021-07-01  40.562821       120.0     -0.367139        0.701446   ZAF
# 2 2021-10-01  42.081780        69.0     -0.331244        0.154151   ZAF
# 3 2022-01-01  40.424068        37.0     -0.370482       -0.456758   ZAF
#
#                                           PARAMETERS
# 0  {'params': [3, (3, 1, 3), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [3, (3, 1, 3), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [3, (3, 1, 3), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [3, (3, 1, 3), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:13
# ######## ZMB (233/234) #########
# 0
# Neighbor countries: ['AGO', 'NAM', 'COD', 'MOZ', 'MWI', 'ZWE', 'TZA', 'BWA']
# Getting Data for ZMB
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (100, 154)
# y: (100, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [3, (0, 1, 0), (0, 0, 0, 0), 'n'], 'cv_score': 0.9878109296453531, 'fold_results': [0.9878109296453531]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_ZMB   No. Observations:                   96
# Model:                SARIMAX(0, 1, 0)   Log Likelihood                -148.025
# Date:                 Sat, 03 Sep 2022   AIC                            304.050
# Time:                         20:13:31   BIC                            314.266
# Sample:                     04-30-1997   HQIC                           308.178
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1643      0.150      1.098      0.272      -0.129       0.458
# x2             0.1073      0.165      0.650      0.516      -0.216       0.431
# x3             0.0320      0.088      0.362      0.717      -0.141       0.205
# sigma2         1.3211      0.153      8.659      0.000       1.022       1.620
# ===================================================================================
# Ljung-Box (L1) (Q):                  14.82   Jarque-Bera (JB):                 8.10
# Prob(Q):                              0.00   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.87   Skew:                             0.28
# Prob(H) (two-sided):                  0.70   Kurtosis:                         4.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 1.5419286532338052, 'gopt': array([-3.66373598e-09, -1.08357767e-08, -8.17124146e-09,  2.36854980e-07]), 'fcalls': 75, 'warnflag': 0, 'converged': True, 'iterations': 6}
# Evaluation started.
# TADDA: 0.519860385419966
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01       3.0         3.0  9.325873e-15        0.000000   ZMB
# 1 2021-07-01       3.0         7.0  9.325873e-15        0.693147   ZMB
# 2 2021-10-01       3.0         3.0  9.325873e-15        0.000000   ZMB
# 3 2022-01-01       3.0         0.0  9.325873e-15       -1.386294   ZMB
#
#                                           PARAMETERS
# 0  {'params': [3, (0, 1, 0), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [3, (0, 1, 0), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [3, (0, 1, 0), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [3, (0, 1, 0), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:14
# ######## ZWE (234/234) #########
# 0
# Neighbor countries: ['MOZ', 'ZMB', 'ZAF', 'BWA']
# Getting Data for ZWE
# IMF, WB, ACLED loaded
# adjusting y for lags
# adjusting X for lags
# GET DATA finished.
# X: (100, 119)
# y: (100, 1)
# ------------------------------------------------
# Training started.
# Start GRIDSEARCH CV on 8 CPU cores:
# 128 parameter combinations are tested.
#   0%|          | 0/128 [00:00<?, ?it/s]
# Best CV-Results
# {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], 'cv_score': 0.8447748905277411, 'fold_results': [0.8447748905277411]}
# Training finished.
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:     SUM(FATALITIES)_ZWE   No. Observations:                   96
# Model:                SARIMAX(2, 1, 1)   Log Likelihood                -124.397
# Date:                 Sat, 03 Sep 2022   AIC                            262.794
# Time:                         20:13:43   BIC                            280.672
# Sample:                     04-30-1997   HQIC                           270.018
#                           - 01-31-2021
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0089      0.028      0.320      0.749      -0.046       0.063
# x2             0.0290      0.050      0.585      0.558      -0.068       0.126
# x3             0.0337      0.045      0.756      0.449      -0.054       0.121
# ar.L1          0.2741      0.131      2.100      0.036       0.018       0.530
# ar.L2          0.1587      0.132      1.206      0.228      -0.099       0.417
# ma.L1         -1.0000     73.862     -0.014      0.989    -145.767     143.767
# sigma2         0.7734     57.101      0.014      0.989    -111.143     112.690
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 3.99
# Prob(Q):                              0.97   Prob(JB):                         0.14
# Heteroskedasticity (H):               0.69   Skew:                             0.49
# Prob(H) (two-sided):                  0.31   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# {'fopt': 1.2958044178103567, 'gopt': array([2.15594653e-05, 8.18313861e-05, 3.08506554e-05, 2.36042075e-05,
#        3.30821814e-05, 3.55271368e-10, 7.43292095e-06]), 'fcalls': 480, 'warnflag': 1, 'converged': False, 'iterations': 50}
# Evaluation started.
# TADDA: 0.7227519400340614
# Evaluation finished.
#        MONTH  FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0 2021-04-01  4.932811         2.0      0.171060       -0.510826   ZWE
# 1 2021-07-01  4.735446         2.0      0.137228       -0.510826   ZWE
# 2 2021-10-01  4.838919        11.0      0.155108        0.875469   ZWE
# 3 2022-01-01  4.836178         3.0      0.154638       -0.223144   ZWE
#
#                                           PARAMETERS
# 0  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
# 1  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
# 2  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
# 3  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
# Execution time: 00:12

# %%
# varimax_res.to_csv("../data/"+MODEL_NAME+"_PREDICTIONS.csv", index=False)

# %%
varimax_res
# Out:
#         MONTH   FAT_PRED  FAT_ACTUAL  LC(FAT_PRED)  LC(FAT_ACTUAL) GID_0  \
# 0  2021-04-01  14.040319        65.0 -9.001834e-01        0.578737   UKR
# 1  2021-07-01  51.140906        28.0  3.430319e-01       -0.243622   UKR
# 2  2021-10-01  19.400422        20.0 -5.953623e-01       -0.566395   UKR
# 3  2022-01-01  46.208753         9.0  2.436614e-01       -1.308333   UKR
# 4  2021-04-01   0.000000         0.0  0.000000e+00        0.000000   URY
# ..        ...        ...         ...           ...             ...   ...
# 79 2022-01-01   3.000000         0.0  9.325873e-15       -1.386294   ZMB
# 80 2021-04-01   4.932811         2.0  1.710603e-01       -0.510826   ZWE
# 81 2021-07-01   4.735446         2.0  1.372275e-01       -0.510826   ZWE
# 82 2021-10-01   4.838919        11.0  1.551078e-01        0.875469   ZWE
# 83 2022-01-01   4.836178         3.0  1.546382e-01       -0.223144   ZWE
#
#                                            PARAMETERS  \
# 0   {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# 1   {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# 2   {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# 3   {'params': [1, (3, 1, 2), (0, 0, 0, 0), 'n'], ...
# 4   {'params': [0, (0, 0, 0), (0, 0, 0, 0), 'n'], ...
# ..                                                ...
# 79  {'params': [3, (0, 1, 0), (0, 0, 0, 0), 'n'], ...
# 80  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
# 81  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
# 82  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
# 83  {'params': [3, (2, 1, 1), (0, 0, 0, 0), 'n'], ...
#
#                     TIMESTAMP
# 0  2022-09-03 20:11:01.180022
# 1  2022-09-03 20:11:01.180022
# 2  2022-09-03 20:11:01.180022
# 3  2022-09-03 20:11:01.180022
# 4  2022-09-03 20:11:11.161758
# ..                        ...
# 79 2022-09-03 20:13:32.383165
# 80 2022-09-03 20:13:44.931988
# 81 2022-09-03 20:13:44.931988
# 82 2022-09-03 20:13:44.931988
# 83 2022-09-03 20:13:44.931988
#
# [84 rows x 8 columns]

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
